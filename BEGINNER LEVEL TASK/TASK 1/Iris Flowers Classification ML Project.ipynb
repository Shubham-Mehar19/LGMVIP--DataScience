# %% [markdown]
# # LGMVIP - DataScience Intern, April-2022
#
# ## Author:- Shubham Mehar
#
# # BEGINNER LEVEL TASK 1
#
# # Iris Flowers Classification ML Project
#
# The Iris flower data set or Fisher's Iris data set is a multivariate data set introduced by the British statistician and biologist Ronald Fisher in his 1936 paper. Iris flowers of three related species. Two of the three species were collected in the Gaspé Peninsula "all from the same pasture, and picked on the same day and measured at the same time by the same person with the same apparatus".The data set consists of 50 samples from each of three species of Iris (Iris setosa, Iris virginica and Iris versicolor). Four features were measured from each sample: the length and the width of the sepals and petals, in centimeters.

# %%
#import libraries

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
#to avoid warnind msg
import warnings
warnings.filterwarnings("ignore")

# %%
#Loading the data

column_names = ['sepal length', 'sepal width', 'petal length', 'petal width', 'class'] #column names

iris=pd.read_csv("iris.data", names=column_names)

# %%
#Checking data
iris.head()
# Out:
#    sepal length  sepal width  petal length  petal width        class
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
#dimension
iris.shape   #(rows,columns)
# Out:
# (150, 5)

# %%
#Info
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal length  150 non-null    float64
#  1   sepal width   150 non-null    float64
#  2   petal length  150 non-null    float64
#  3   petal width   150 non-null    float64
#  4   class         150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
#finding missing values
iris.isnull().sum()
# Out:
# sepal length    0
# sepal width     0
# petal length    0
# petal width     0
# class           0
# dtype: int64

# %%
#Descriptive statistics
iris.describe()
# Out:
#        sepal length  sepal width  petal length  petal width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# # Data Visualization

# %%
#Pairplot
sns.pairplot(data=iris, hue="class",palette="rocket")

# %% [markdown]
# From the pairplot it is evident that iris-setosa is easily separable.

# %%
#Checking data ditribution based on class

plt.figure(figsize=(16,5))
plt.subplot(1,2,1)
sns.countplot(iris["class"],palette="rocket")

plt.subplot(1,2,2)
iris["class"].value_counts().plot(kind="pie",autopct="%.2f", explode=(0.05,0.05,0.05))
plt.title("class", fontsize= 19, c= "brown")
plt.show()

# %% [markdown]
# The data ie evenly distributed.

# %%
# Distribution plot

iris.hist(figsize=(16,8),color="orange")
plt.show()

# %%
#Distribution plot with KDE

plt.figure(figsize=(20,20))
plt.subplot(2,2,1)
sns.distplot(iris["sepal length"], color="brown")

plt.subplot(2,2,2)
sns.distplot(iris["sepal width"], color="gold")

plt.subplot(2,2,3)
sns.distplot(iris["petal length"], color="blue")

plt.subplot(2,2,4)
sns.distplot(iris["petal width"], color="orange")
plt.show()

# %%
plt.figure(figsize=(16,8))
sns.boxplot(data=iris,palette="rocket" )
# Out:
# <AxesSubplot:>

# %% [markdown]
# No outliers are present in the dataset.

# %% [markdown]
# ## Scatter plot "sepal length" vs "sepal width"

# %%
plt.figure(figsize=(16,8))
sns.scatterplot(iris["sepal length"], iris["sepal width"], hue= iris["class"],marker='*',  s = 200)
plt.title("sepal length Vs sepal width")
plt.show()

# %% [markdown]
# Iris-setosa sepal width lies between 3.0 to 4.5 and sepal length is 4.0 to 6.0.
#
# Iris-versicolor sepal width lies between 2.0 to 3.5 and sepal length is 5.0 to 7.0.
#
# Iris-versicolor sepal width lies between 2.5 to 4.0 and sepal length is 5.5 to 8.0.

# %% [markdown]
# ## Scatterplot "petal length" Vs "petal width"

# %%
plt.figure(figsize=(16,8))
sns.scatterplot(iris["petal length"], iris["petal width"], hue= iris["class"],marker='*',  s = 200)
plt.title("petal length Vs petal width")
plt.show()

# %% [markdown]
# Iris-setosa petal length lies between 1 to 2 and petal width is 0 to 1.
#
# Iris-versicolor petal length lies between 3 to 5 and petal width is 1 to 1.75.
#
# Iris-versicolor petal length lies between 5 to 7 and petal width is 1.5 to 2.5.

# %%
# bar plots

# %%
plt.figure(figsize= (16,16))
plt.subplot(2,2,1)
sns.barplot(x= "class", y = "petal width", data = iris, palette= "rocket")

plt.subplot(2,2,2)
sns.barplot(x= "class", y = "petal length", data = iris, palette= "rocket")

plt.subplot(2,2,3)
sns.barplot(x= "class", y = "sepal length", data = iris, palette= "rocket")

plt.subplot(2,2,4)
sns.barplot(x= "class", y = "sepal width", data = iris, palette= "rocket")
# Out:
# <AxesSubplot:xlabel='class', ylabel='sepal width'>

# %% [markdown]
# The inferences we made from the above two scatter plots are correct and it is clearly seen from bar plots as well.

# %%
#heatmap
plt.figure(figsize=(16,8))
sns.heatmap(iris.corr(), annot=True, cmap="rocket")
# Out:
# <AxesSubplot:>

# %% [markdown]
# Sepal width showing negative correlation with class.

# %% [markdown]
# # Data preparation

# %%
iris["class"].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %% [markdown]
# ## Label Encoding

# %% [markdown]
# LabelEncoder can be used to normalize labels. It can also be used to transform non-numerical labels (as long as they are hashable and comparable) to numerical labels.

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

iris['class'] = le.fit_transform(iris['class'])
iris.head()
# Out:
#    sepal length  sepal width  petal length  petal width  class
# 0           5.1          3.5           1.4          0.2      0
# 1           4.9          3.0           1.4          0.2      0
# 2           4.7          3.2           1.3          0.2      0
# 3           4.6          3.1           1.5          0.2      0
# 4           5.0          3.6           1.4          0.2      0

# %%
iris["class"].unique()
# Out:
# array([0, 1, 2])

# %% [markdown]
# # Train Test Split
#
# Now let's split the data into a training set and a testing set. We will train out model on the training set and then use the test set to evaluate the model. Taking training data 80% and 20% for model testing.

# %%
from sklearn.model_selection import train_test_split

# %%
X=iris.drop("class",axis=1)
y=iris["class"]

# %%
print(X.shape)
print(y.shape)
# Out:
# (150, 4)
# (150,)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=19)

# %% [markdown]
# # Supervised Machine Learning Algorithm

# %% [markdown]
# Supervised machine learning is defined by its use of labeled datasets to train algorithms that to classify data or predict outcomes accurately.
#
# 1. Logistic Regression
# 2. Support Vector Machines
# 3. Decision Tree
# 4. Random Forest
# 5. Naïve Bayes Classification
# 6. KNN

# %% [markdown]
# # Logistic Regression Model

# %%
from sklearn.linear_model import LogisticRegression

# %%
logmodel = LogisticRegression()
logmodel.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
#predictions and evaluation
predictions = logmodel.predict(X_test)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        10
#            1       1.00      1.00      1.00        12
#            2       1.00      1.00      1.00         8
#
#     accuracy                           1.00        30
#    macro avg       1.00      1.00      1.00        30
# weighted avg       1.00      1.00      1.00        30

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_test,predictions)
print("Accuracy of logistic Regression Model: ", accuracy*100) # in %
# Out:
# Accuracy of logistic Regression Model:  100.0

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(y_test,predictions))
# Out:
# [[10  0  0]
#  [ 0 12  0]
#  [ 0  0  8]]

# %% [markdown]
# # Decision Tree Model

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtree = DecisionTreeClassifier()

# %%
dtree.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
predictions = dtree.predict(X_test)

# %%
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        10
#            1       1.00      1.00      1.00        12
#            2       1.00      1.00      1.00         8
#
#     accuracy                           1.00        30
#    macro avg       1.00      1.00      1.00        30
# weighted avg       1.00      1.00      1.00        30

# %%
accuracy = accuracy_score(y_test,predictions)
print("Accuracy of Decision Tree Model: ", accuracy*100) # in %
# Out:
# Accuracy of Decision Tree Model:  100.0

# %%
print(confusion_matrix(y_test,predictions))
# Out:
# [[10  0  0]
#  [ 0 12  0]
#  [ 0  0  8]]

# %% [markdown]
# # Random Forest model

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rfc = RandomForestClassifier()

# %%
rfc.fit(X_train,y_train)
# Out:
# RandomForestClassifier()

# %%
predictions = rfc.predict(X_test)

# %%
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        10
#            1       0.92      1.00      0.96        12
#            2       1.00      0.88      0.93         8
#
#     accuracy                           0.97        30
#    macro avg       0.97      0.96      0.96        30
# weighted avg       0.97      0.97      0.97        30

# %%
accuracy = accuracy_score(y_test,predictions)
print("Accuracy of Random Forest Model: ", accuracy*100) # in %
# Out:
# Accuracy of Random Forest Model:  96.66666666666667

# %%
print(confusion_matrix(y_test,predictions))
# Out:
# [[10  0  0]
#  [ 0 12  0]
#  [ 0  1  7]]

# %% [markdown]
# # K Nearest Neighbour Model

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
knn = KNeighborsClassifier(n_neighbors=1)

# %%
knn.fit(X_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=1)

# %%
pred = knn.predict(X_test)

# %%
print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        10
#            1       1.00      1.00      1.00        12
#            2       1.00      1.00      1.00         8
#
#     accuracy                           1.00        30
#    macro avg       1.00      1.00      1.00        30
# weighted avg       1.00      1.00      1.00        30

# %%
accuracy = accuracy_score(y_test,pred)
print("Accuracy of KNN Model: ", accuracy*100) # in %
# Out:
# Accuracy of KNN Model:  100.0

# %%
print(confusion_matrix(y_test,pred))
# Out:
# [[10  0  0]
#  [ 0 12  0]
#  [ 0  0  8]]

# %% [markdown]
# # Support Vector Machine Model

# %%
from sklearn.svm import SVC

# %%
svc_model = SVC()

# %%
svc_model.fit(X_train,y_train)
# Out:
# SVC()

# %%
predictions = svc_model.predict(X_test)

# %%
print(classification_report(y_test,predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        10
#            1       1.00      1.00      1.00        12
#            2       1.00      1.00      1.00         8
#
#     accuracy                           1.00        30
#    macro avg       1.00      1.00      1.00        30
# weighted avg       1.00      1.00      1.00        30

# %%
accuracy = accuracy_score(y_test,predictions)
print("Accuracy of Support Vector Machine Model: ", accuracy*100) # in %
# Out:
# Accuracy of Support Vector Machine Model:  100.0

# %%
print(confusion_matrix(y_test,predictions))
# Out:
# [[10  0  0]
#  [ 0 12  0]
#  [ 0  0  8]]

# %% [markdown]
# # Naïve Bayes Classification Model

# %%
from sklearn.naive_bayes import GaussianNB

# %%
gnb = GaussianNB()

# %%
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
pred = gnb.predict(X_test)

# %%
print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        10
#            1       0.92      1.00      0.96        12
#            2       1.00      0.88      0.93         8
#
#     accuracy                           0.97        30
#    macro avg       0.97      0.96      0.96        30
# weighted avg       0.97      0.97      0.97        30

# %%
accuracy = accuracy_score(y_test,pred)
print("Accuracy of Support Vector Machine Model: ", accuracy*100) # in %
# Out:
# Accuracy of Support Vector Machine Model:  96.66666666666667

# %%
print(confusion_matrix(y_test,pred))
# Out:
# [[10  0  0]
#  [ 0 12  0]
#  [ 0  1  7]]

# %% [markdown]
# # Inference
#
# The dataset is very small, so we are getting accuracy 100% in most of the algorithms.
#
# 	Accuracy of Logistic Regression :- 100 %
#
# 	Accuracy of Decision Tree :- 100 %
#
# 	Accuracy of Random Forest Classifier :- 100 %
#
# 	Accuracy of Support Vecor Machine :- 100 %
#
# 	Accuracy of K Nearest Neighbors Classifier :- 100%
#
# 	Accuracy of Naive Bayes :- 96.66 %

# %% [markdown]
# # Testing the model by giving the input

# %%
iris.columns
# Out:
# Index(['sepal length', 'sepal width', 'petal length', 'petal width', 'class'], dtype='object')

# %%
def prediction():
    sepallength=input("sepal length:")
    sepalwidth=input("sepal width:")
    petallength=input("petal length:")
    petalwidth=input("petal width:")

    result = rfc.predict([[sepallength, sepalwidth, petallength, petalwidth]])
    
    if result ==[0]:
        return "The Class of iris flower is 'Iris Setosa'"
    elif result ==[1]:
        return "The Class of iris flower is 'Iris Versicolour'"
    else:
        return "The Class of iris flower is 'Iris Virginica'"

# %%
prediction()
# Out:
# sepal length:4
# sepal width:18
# petal length:18
# petal width:18
# "The Class of iris flower is 'Iris Virginica'"

# %%
__IN__=10

# %%
IN=10

# %%
it=10

# %%
on=10

# %%
in=10
# Out:
#   File "<ipython-input-74-aaad21344826>", line 1
#     in=10
#     ^
# SyntaxError: invalid syntax

# %%
x=3*1**3

# %%
print(x)
# Out:
# 3

# %%
def power(x, y=2):
    r=1
    for i in range(y):
        r=r*x
    return r
print(power(3))
print(power(3,3))
# Out:
# 9
# 27

# %%
x=2
for i in range (x):
    x-=2
    print(x)
# Out:
# 0
# -2

# %%
d={0,1,2}
for x in d:
    print(d.add(x))
# Out:
# None
# None
# None

# %%
try:
    if '1' != 1:
        raise "someError"
    else:
        print("someError has not occured")
except "someError":
    print("someError has occured")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-87-1758e153a2b9> in <module>
#       2     if '1' != 1:
# ----> 3         raise "someError"
#       4     else:
#
# TypeError: exceptions must derive from BaseException
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-87-1758e153a2b9> in <module>
#       4     else:
#       5         print("someError has not occured")
# ----> 6 except "someError":
#       7     print("someError has occured")
#
# TypeError: catching classes that do not inherit from BaseException is not allowed

# %%
y=-5
z=lambda x:x%y*6
print(z(6))
# Out:
# -24

# %%
x="abcd"
for i in range(len(x)):
    i[x].upper()
print(x)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-89-7afb5b92142f> in <module>
#       1 x="abcd"
#       2 for i in range(len(x)):
# ----> 3     i[x].upper()
#       4 print(x)
#
# TypeError: 'int' object is not subscriptable

# %%
def foo(i, x=[]):
    x.append(x.append(i))
    return x
for i in range(3):
    y=foo(i)
print(y)
# Out:
# [0, None, 1, None, 2, None]

# %%
set1={1,2,3}
set2={4,5,6}
print(len(set1 + set2))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-93-c03e4b2020ce> in <module>
#       1 set1={1,2,3}
#       2 set2={4,5,6}
# ----> 3 print(len(set1 + set2))
#
# TypeError: unsupported operand type(s) for +: 'set' and 'set'

# %%
data=50
try:
    data=data/0
except ZeroDivisionError:
    print("Cannot divide by 0", end="")
else:
    print("Division successful", end="")
try:
    data=data/5
except:
    print("Inside except block", end="")
else:
    print("GFG", end="")
# Out:
# Cannot divide by 0GFG

# %%
a={5,6,7,8}
b={7,8,9,10}
len(a+b)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-95-cc67da145679> in <module>
#       1 a={5,6,7,8}
#       2 b={7,8,9,10}
# ----> 3 len(a+b)
#
# TypeError: unsupported operand type(s) for +: 'set' and 'set'

# %%
a=("check",)
n=2
for i in range(int(n)):
    a=(a,)
    print(a)
# Out:
# (('check',),)
# ((('check',),),)

# %%
m=[[x,x+1,x+2] for x in range(0,3)]
m
# Out:
# [[0, 1, 2], [1, 2, 3], [2, 3, 4]]

# %%
total={}
def insert(items):
    if items in total:
        total[items]+=1
    else:
        total[items]=1
insert("a")
insert("b")
insert("a")
print(len(total))
# Out:
# 2
